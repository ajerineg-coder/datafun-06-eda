# %% [markdown]
# # Custom EDA: Palmer Penguins
#
# **Author:** Addie Gemmell
# **Date:** February 2026
#
# This notebook performs exploratory data analysis (EDA) on the Palmer Penguins dataset to explore differences among penguin species and relationships between physical measurements.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Species Distribution
#
# This section examines the distribution of penguin species in the cleaned dataset.

# %%
df = sns.load_dataset("penguins")
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ## Data Cleaning
#
# The dataset contained a small number of missing values, particularly in the `sex` column and some numeric measurement columns.
#
# To ensure accurate analysis and visualizations, rows with missing values were removed.

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %% [markdown]
# ## Species Distribution
#
# This section examines the distribution of penguin species in the cleaned dataset.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    str
#  1   island             344 non-null    str
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    str
# dtypes: float64(4), str(3)
# memory usage: 24.9 KB

# %%
sns.countplot(data=df_clean, x="species")
plt.title("Count of Penguin Species")
plt.show()

# %% [markdown]
# ## Summary
#
# The analysis shows clear differences in species distribution within the Palmer Penguins dataset. Adelie penguins are the most common species, followed by Gentoo and Chinstrap. Cleaning the dataset by removing missing values ensured accurate visualization and comparison.

# %%
df_clean = df.dropna()
df_clean.shape
# Out:
# (333, 7)

# %% [markdown]
# ### Interpretation
#
# The distribution shows that Adelie penguins are the most common species in the dataset, followed by Gentoo and Chinstrap. The species are not evenly represented, which is important to consider when comparing measurements across groups.

# %%
df.shape
# Out:
# (344, 7)

# %%
sns.countplot(data=df_clean, x="species")
plt.title("Count of Penguin Species")
plt.show()
